# %%
names = []

for _ in range(3):
    names.append(input("What's your name? "))

for name in sorted(names):
    print(f"hello {name}")

# %%
with open("hello.txt", "r") as file:
    lines = file.readlines()
    print(lines)
# Out:
# ['feghervk\n', 'ehkbw\n', 'veqob\n', 'bekrgbev\n']

# %%
with open("names.csv", "r") as pokeball:
     for line in sorted(pokeball):
          print(f"I choose you, {line.rstrip()}!")
# Out:
# I choose you, Charizard,Fire!
# I choose you, Pikachu,Electric!
# I choose you, Squirtle,Water!

# %%
pokemon_list = []

with open("s.csv") as file:
    for line in file:
        pok, type = line.rstrip().split(",")
        pokemon={"pok": pok, "type": type}
        pokemon_list.append(pokemon)

for p in sorted(pokemon_list, key = lambda pokemon: pokemon['pok']):
    print(f"{p['pok']}! {p['type']}!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 5
#       3 with open("s.csv") as file:
#       4     for line in file:
# ----> 5         pok, type = line.rstrip().split(",")
#       6         pokemon={"pok": pok, "type": type}
#       7         pokemon_list.append(pokemon)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
import csv

pokemon_list = []

with open("s.csv") as file:
    r = csv.DictReader(file)
    for row in r:
        pokemon_list.append({"name": row["Name"], "attack": row['Attack']})

for p in sorted(pokemon_list, key=lambda pokemon: pokemon["name"]):
    print(f"{p['name']}! {p['attack']}!")
# Out:
# Charizard! flame, thrower!
# Pikachu! thunder!
# Squirtle! Water!

# %%
import csv 

name = input("What's your name?")
home = input("Where is your home?")

with open("s.csv", "a") as file:
    writer = csv.DictWriter(file, fieldnames = ["name", "home"])
    writer.writerow({"name": name, "home": home})

# %%
import sys

from PIL import Image

images = []

for arg in sys.argv[1:]:
    image = Image.open(arg)
    images.append(image)

image[0].save(
    "costumes.gif", save_all=True, append_images=[images[1]], duration=200, loop=0
)
