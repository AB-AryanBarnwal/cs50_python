# %%
#fliping a coin
from random import choice

coin = choice(["H", "T"])


print(coin)
# Out:
# H

# %%
import random

lst = ["1", "2", "3", "4", "5", "6"]
random.shuffle(lst)

for i in lst:
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 1

# %%
import statistics

print(statistics.mean([100, 90]))
# Out:
# 95

# %%
import sys
try:
    print("hello, my name is", sys.argv[9])
except:
    print("too few arguements")
# Out:
# too few arguements

# %%
import sys

if len(sys.argv) < 2:
    sys.exit("Too few arguements")

for arg in sys.argv[1:]:
    print("Hello my name is ", arg)

# %%
import cowsay
import sys

if len(sys.argv) == 2:
    cowsay.trex("hello, " + sys.argv[1])
# Out:
#   ______________
# | hello, pokemon |
# ...
#                      \
#                       \
#                        \
#                         \
#                            .-=-==--==--.
#                      ..-=="  ,'o`)      `.
#                    ,'         `"'         \
#                   :  (                     `.__...._
#                   |                  )    /         `-=-.
#                   :       ,vv.-._   /    /               `---==-._
#                    \/\/\/VV ^ d88`;'    /                         `.
#                        ``  ^/d88P!'    /             ,              `._
#                           ^/    !'   ,.      ,      /                  "-,,__,,--'""""-.
#                          ^/    !'  ,'  \ . .(      (         _           )  ) ) ) ))_,-.\
#                         ^(__ ,!',"'   ;:+.:%:a.     \:.. . ,'          )  )  ) ) ,"'    '
#                         ',,,'','     /o:::":%:%a.    \:.:.:         .    )  ) _,'
# ...

# %%
import requests

inp = input("Name")

r = requests.get("https://itunes.apple.com/search?entity=song&limit=25&term=" + inp)

o = r.json()
for res in o["results"]:
    print(res["trackName"])
# Out:
# Monster
# Hero
# Awake and Alive
# The Resistance
# Feel Invincible
# Comatose
# Whispers In the Dark
# Not Gonna Die
# Legendary
# Rise
# Save Me
# Sick of It
# Stars
# Finish Line
# Falling Inside the Black
# Rebirthing
# Burn It Down
# Lions
# Back from the Dead
# The Last Night
# Psycho In My Head
# Anchor
# Skillet
# It's Not Me, It's You
# Undefeated

# %%
def hello(name):
    print(f"hello, {name}")

def good_bye(name):
    print(f"goodbye {name}")

def main():
    hello("me")
    good_bye("you")

if __name__ == "__main__":
    main()
# Out:
# hello, me
# goodbye you

# %%
import requests


def main():
    print("Search the Art Institue of Chicago")
    artist = input("Artist:")
    try:
        response = requests.get(
            "https://api.artic.edu/api/v1/artworks/search",
            {"q": artist}
            )
        response.raise_for_status()
    except requests.HTTPError:
        print("Couldn't complete request")
    return
    
    content = response.json()
    for artwork in content["data"]:
        print(f"* {artwork['title']}")

    print(content)
    


main()
# Out:
# Search the Art Institue of Chicago
# * The Bedroom
# * Self-Portrait
# * The Poet's Garden
# * A Peasant Woman Digging in Front of Her Cottage
# * The Drinkers
# * Fishing in Spring, the Pont de Clichy (Asnières)
# * Madame Roulin Rocking the Cradle (La berceuse)
# * Terrace and Observation Deck at the Moulin de Blute-Fin, Montmartre
# * Grapes, Lemons, Pears, and Apples
# * Weeping Tree
# ...
