# %%
#This is a comment 
name = input("your name? ")
print("hello", name)
# Out:
# hello a

# %%
#These are pseudocode. used for structuring the code

#Ask for name
#Say hello to users

# %%
print("hello, \"friends\"")
# Out:
# hello, "friends"

# %%
#fstring
name = input("your name? ")
print(f"hello, {name}")
# Out:
# hello,           a

# %%
#remove whitespace and capitalize the string
name = input("your name? ").strip().title()
#split user's name intro first and last name
first, last = name.split(" ")
print(f"hello, {first}")
# Out:
# hello, Tony

# %%
#Calculator

x = float(input("What is first number? "))
y = float(input("What is second number? "))

# z = round(x+y)
# print(f"{z:,}")

z = x/y
print(f"{z:.3f}")
# Out:
# 0.667

# %%
#functions
def hello(n):
    print("hello", n)


def main():
    name = input("Your Name?")
    hello(name)

main()
# Out:
# hello a

# %%
#another cal

def square(n):
    return pow(n, 2)

def main():
    x = int(input("what is x?"))
    print(f"{x} square:", square(x))

main()
# Out:
# 5 square: 25
